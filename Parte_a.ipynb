# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# Dados de tensão (A0-V até A5-V)
tensoes1 = [[5.0000,	4.9756,	3.9736,	2.9765,	1.9795,	0.9824],
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9873],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9873],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9658,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[4.9951,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[4.9951,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9785,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9609,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9756,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9824],	
[5.0000,	4.9707,	3.9834,	2.9765,	1.9795,	0.9775],	
[5.0000,	4.9658,	3.9834,	2.9765,	1.9795,	0.9775],
[5.0000,	4.9756,	3.9785,	2.9765,	1.9795,	0.9824]]	

tensoes = list(list(tensoes1[j][0]-tensoes1[j][i+1] for i in range(5)) for j in range(len(tensoes1)))
for i in tensoes:
    i.append(5)


tensoes = np.array(tensoes)

# Resistências totais (em Ω): 1, 2, 3, 4, 5 resistores de 300Ω e 5 resistores + 10Ω
resistencias = np.array([10, 310, 610, 910, 1210, 1510])  # Resistores de 300Ω, mais 10Ω no final para VA0

# Calcular médias das tensões para cada configuração
media_tensoes = np.mean(tensoes, axis=0)

# Incertezas nas medições de resistência (5% de erro nos resistores de 300Ω)
dR = 0.05 * resistencias  # 5% de erro na resistência

# Incerteza na tensão (4.9mV devido ao ADC do Arduino)
dV = 0.0049  # 4.9 mV de resolução

# Plotando o gráfico de V versus R com incertezas
plt.figure(figsize=(8, 6))
plt.errorbar(resistencias, media_tensoes, xerr=dR, yerr=dV, fmt='o', label='Dados experimentais', capsize=5)

# Ajuste linear (reta)
slope, intercept, r_value, p_value, std_err = stats.linregress(resistencias, media_tensoes)

# Coeficiente angular (corrente I) da reta
corrente = slope / resistencias[0]
print(f'Coeficiente angular (corrente): {corrente:.3f} A')

# Adicionando a reta de ajuste
x_line = np.linspace(0, resistencias[-1], 100)
y_line = slope * x_line + intercept
plt.plot(x_line, y_line, 'r-', label=f'Ajuste linear: y = {slope:.2f}x + {intercept:.2f}')

# Adicionando a linha passando por (0 Ω, 0 V)
plt.plot([0, 1510], [0, 5], 'b--', label='Reta ligando (0,0) - (1510, 5)')

# Personalizando o gráfico
plt.title('Tensão vs Resistência')
plt.xlabel('Resistência Total (Ω)')
plt.ylabel('Tensão (V)')
plt.legend()
plt.grid(True)
#plt.plot([1530.2], [5], 'ro', color='green')
#plt.plot([1469.8], [5], 'ro', color='green')

# Exibindo o gráfico
plt.show()

# Calcular a corrente pela diferença de tensão (VA0 - VA1) / 10
I_calculada = (media_tensoes[-1] - media_tensoes[-2]) / 10  # VA0 - VA1 / 10Ω

print('a corrente de acordo com o ajuste é:', slope)









## aqui esta gráfico e a corrente de acordo com o ajuste linear
# Out:
# Coeficiente angular (corrente): 0.000 A
# a corrente de acordo com o ajuste é: 0.0033196048444811463

# %%
ddp = list(list(tensoes1[j][i]- tensoes1[j][i+1] for i in range(5)) for j in range(len(tensoes1)))


for i in range(len(tensoes1)):
    ddp[i].append(tensoes1[i][-1])
  

ddp = np.array(ddp)
ddp



## Isso a aqui e um array com o decaimento de potencial causado por cada um dos resistores
# Out:
# array([[0.0244, 1.002 , 0.9971, 0.997 , 0.9971, 0.9824],
#        [0.0342, 0.9824, 1.0069, 0.997 , 0.9971, 0.9824],
#        [0.0244, 0.9922, 1.0069, 0.997 , 1.002 , 0.9775],
#        ...,
#        [0.0293, 0.9873, 1.0069, 0.997 , 1.002 , 0.9775],
#        [0.0342, 0.9824, 1.0069, 0.997 , 1.002 , 0.9775],
#        [0.0244, 0.9971, 1.002 , 0.997 , 0.9971, 0.9824]])

# %%
correntes = ddp/slope

# %%
dados = pd.DataFrame(correntes, columns=["d1-0", "d2-1", "d3-2", "d4-3", "d5-4", "d6-5"])
dados
# Out:
#           d1-0        d2-1        d3-2        d4-3        d5-4        d6-5
# 0     7.350272  301.843155  300.367076  300.336952  300.367076  295.938838
# 1    10.302431  295.938838  303.319234  300.336952  300.367076  295.938838
# 2     7.350272  298.890997  303.319234  300.336952  301.843155  294.462759
# 3     8.826352  297.414917  303.319234  300.336952  301.843155  294.462759
# 4     8.826352  295.938838  303.319234  300.336952  300.367076  295.938838
# ..         ...         ...         ...         ...         ...         ...
# 168   7.350272  298.890997  303.319234  300.336952  300.367076  295.938838
# 169  10.302431  295.938838  303.319234  300.336952  300.367076  295.938838
# 170   8.826352  297.414917  303.319234  300.336952  301.843155  294.462759
# 171  10.302431  295.938838  303.319234  300.336952  301.843155  294.462759
# 172   7.350272  300.367076  301.843155  300.336952  300.367076  295.938838
#
# [173 rows x 6 columns]

# %%
std_dev = dados.std()

incerteza = std_dev/np.sqrt(dados.count())
media = dados.mean()
print('incerteza:\n',incerteza, "\n\n\n")
print('media:\n', media)




### isso daqui sao as medias das medicoes de resistencias e a incertezas praticas.
# Out:
# incerteza:
#  d1-0    8.727450e-02
# d2-1    1.021014e-01
# d3-2    5.583612e-02
# d4-3    8.668540e-15
# d5-4    5.794894e-02
# d6-5    5.794894e-02
# dtype: float64
#
#
#
# media:
#  d1-0      8.715432
# d2-1    297.858594
# d3-2    302.764638
# d4-3    300.336952
# d5-4    300.972866
# d6-5    295.333048
# dtype: float64

# %%
df = pd.DataFrame(ddp, columns=["A0", "A1", "A2", "A3", "A4", "A5"])
df


## Ate agora, fizemos todos os calculos como se a corrente obtida pelo ajuste linear. Agora faremos as medidas das correntes
##supondo um shunt ideal de 10 ohms. Mediremos as correntes a cada instante e  os o faremos resultados das resistencias atraves delas

## Isso aqui e um dataframe com os valores dos decaimentos de potencial causados por cada um dos resistores
# Out:
#          A0      A1      A2     A3      A4      A5
# 0    0.0244  1.0020  0.9971  0.997  0.9971  0.9824
# 1    0.0342  0.9824  1.0069  0.997  0.9971  0.9824
# 2    0.0244  0.9922  1.0069  0.997  1.0020  0.9775
# 3    0.0293  0.9873  1.0069  0.997  1.0020  0.9775
# 4    0.0293  0.9824  1.0069  0.997  0.9971  0.9824
# ..      ...     ...     ...    ...     ...     ...
# 168  0.0244  0.9922  1.0069  0.997  0.9971  0.9824
# 169  0.0342  0.9824  1.0069  0.997  0.9971  0.9824
# 170  0.0293  0.9873  1.0069  0.997  1.0020  0.9775
# 171  0.0342  0.9824  1.0069  0.997  1.0020  0.9775
# 172  0.0244  0.9971  1.0020  0.997  0.9971  0.9824
#
# [173 rows x 6 columns]

# %%
df__= df["A0"]/10
df__

## isso daqui e a corrente que passa pelos resistores a cada instante de medida
# Out:
# 0      0.00244
# 1      0.00342
# 2      0.00244
# 3      0.00293
# 4      0.00293
#         ...
# 168    0.00244
# 169    0.00342
# 170    0.00293
# 171    0.00342
# 172    0.00244
# Name: A0, Length: 173, dtype: float64

# %%
correntes = df["A1"]/df__
correntes

#isso aqui e o resultado das resistencias a cada insatante. troque as coluna para verificar os resultados de cada uma delas.
#faca isso e execute essa celula e a celula de baixo
# Out:
# 0      410.655738
# 1      287.251462
# 2      406.639344
# 3      336.962457
# 4      335.290102
#           ...
# 168    406.639344
# 169    287.251462
# 170    336.962457
# 171    287.251462
# 172    408.647541
# Length: 173, dtype: float64

# %%
print(correntes.std())
correntes.mean()



#isso e o desvio padra e a corrente a cada instante
# Out:
# 48.90181583270084
# 348.0797172155945
