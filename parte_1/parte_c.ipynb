# %%
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
import pandas as pd

# %%
tensoes = [[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7400,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7400,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7400,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[4.9951,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[4.9951,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[4.9951,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[4.9951,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000],	
[5.0000,	2.1408,	1.8573,	1.7449,	1.6862,	0.0000]]

# %%
tensoes = np.array(tensoes)
df_tensoes = pd.DataFrame(tensoes, columns=['A0', 'A1', 'A2', 'A3', 'A4', 'A5'])
df_tensoes
# Out:
#       A0      A1      A2      A3      A4   A5
# 0    5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 1    5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 2    5.0  2.1408  1.8573  1.7400  1.6862  0.0
# 3    5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 4    5.0  2.1408  1.8573  1.7449  1.6862  0.0
# ..   ...     ...     ...     ...     ...  ...
# 108  5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 109  5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 110  5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 111  5.0  2.1408  1.8573  1.7449  1.6862  0.0
# 112  5.0  2.1408  1.8573  1.7449  1.6862  0.0
#
# [113 rows x 6 columns]

# %%
correntes_R1 = (df_tensoes["A1"]-df_tensoes["A2"])/10.15
correntes_R1


## Calcule as correntes usando as quedas de tensão nos shunts (~10 Ω): Itotal (a corrente que passa em R10R1). Aqui, utilizei
#os valores das resistencias calibradas pelo arduino.



#Aqui estao as correntes que passam por R1
# Out:
# 0      0.027931
# 1      0.027931
# 2      0.027931
# 3      0.027931
# 4      0.027931
#          ...
# 108    0.027931
# 109    0.027931
# 110    0.027931
# 111    0.027931
# 112    0.027931
# Length: 113, dtype: float64

# %%
correntes_R2 = (df_tensoes["A2"]-df_tensoes["A3"])/10.22
correntes_R2.mean()


## Aqui estao as correntes de R2
# Out:
# 0.011010771868451591

# %%
correntes_R3 = (df_tensoes["A2"]-df_tensoes["A4"])/10.62
correntes_R3


## Aqui estao as correntes de R3
# Out:
# 0      0.016111
# 1      0.016111
# 2      0.016111
# 3      0.016111
# 4      0.016111
#          ...
# 108    0.016111
# 109    0.016111
# 110    0.016111
# 111    0.016111
# 112    0.016111
# Length: 113, dtype: float64

# %%
resistencia_equivalente_braco_1 = df_tensoes["A2"]/correntes_R2
resistencia_equivalente_braco_1
# Out:
# 0      168.875498
# 1      168.875498
# 2      161.821023
# 3      168.875498
# 4      168.875498
#           ...
# 108    168.875498
# 109    168.875498
# 110    168.875498
# 111    168.875498
# 112    168.875498
# Length: 113, dtype: float64

# %%
resistencia_equivalente_braco_2 = df_tensoes["A2"]/correntes_R3
resistencia_equivalente_braco_2
# Out:
# 0      115.28069
# 1      115.28069
# 2      115.28069
# 3      115.28069
# 4      115.28069
#          ...
# 108    115.28069
# 109    115.28069
# 110    115.28069
# 111    115.28069
# 112    115.28069
# Length: 113, dtype: float64

# %%
resistencia_equivalente_sistema_total = df_tensoes["A0"]/correntes_R1
resistencia_equivalente_sistema_total
# Out:
# 0      179.012346
# 1      179.012346
# 2      179.012346
# 3      179.012346
# 4      179.012346
#           ...
# 108    179.012346
# 109    179.012346
# 110    179.012346
# 111    179.012346
# 112    179.012346
# Length: 113, dtype: float64

# %%
resisten
