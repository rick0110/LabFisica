# %%
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import numpy as np


dados = pd.DataFrame(np.array([[0.9824,	1.9795,	2.9765,	3.9736,	4.9658,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9736,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9658,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9785,	4.9609,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9658,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	4.9951],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9707,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9609,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9785,	4.9756,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9736,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9658,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9658,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	4.9951],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9736,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9658,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9658,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9658,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9609,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9658,	4.9902],	
[0.9824,	1.9795,	2.9765,	3.9736,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9736,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9775,	1.9746,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	4.9902],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	4.9902],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9658,	4.9902],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9658,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9658,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9658,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9736,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9658,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9707,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	4.9951],	
[0.9873,	1.9746,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9756,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9736,	4.9658,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9658,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9658,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9873,	1.9795,	2.9765,	3.9834,	4.9658,	5.0000],	
[0.9824,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9785,	4.9756,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	4.9951],	
[0.9824,	1.9795,	2.9765,	3.9785,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9707,	5.0000],	
[0.9775,	1.9795,	2.9765,	3.9834,	4.9609,	5.0000]]), columns=["A0", "A1", "A2", "A3", "A4", "A5"])

# %%
dados.insert(6, "corrente0", pd.Series([i/10 for i in dados["A0"]]))
for i in range(1, 6):
    dados.insert(i + 6, f'resistencia{i}', pd.Series([i/300 for i in dados[f'A{i}']]))
print(dados)
# Out:
#      A0      A1      A2      A3      A4      A5  corrente0  corrente1  \
# 0   5.0  4.9658  3.9834  2.9765  1.9795  0.9824        0.5   0.016553
# 1   5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# 2   5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# 3   5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# 4   5.0  4.9707  3.9834  2.9765  1.9795  0.9824        0.5   0.016569
# 5   5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# 6   5.0  4.9707  3.9834  2.9765  1.9795  0.9824        0.5   0.016569
# 7   5.0  4.9707  3.9834  2.9765  1.9795  0.9824        0.5   0.016569
# 8   5.0  4.9707  3.9834  2.9765  1.9795  0.9824        0.5   0.016569
# 9   5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# 10  5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# 11  5.0  4.9707  3.9785  2.9765  1.9795  0.9824        0.5   0.016569
# ...

# %%
fig = plt.figure()
fig, ax = plt.subplots()
ax.set_xlabel('V')
ax.set_ylabel('Omhs')
ax.plot([0,5], [0, 1500], color='blue')
plt.show()
